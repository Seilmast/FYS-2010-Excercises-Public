# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = 'Data/Fig0227(a)(washington_infrared).tif'
img = Image.open(img_path)

plt.figure()
plt.imshow(img, cmap='gray')
plt.show()
